# %% [markdown]
# # Automated Project: Planning, Estimation, and Allocation

# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from helper import load_env
load_env()

import os
import yaml
from crewai import Agent, Task, Crew

# %% [markdown]
# ## Set OpenAI Model

# %%
os.environ['OPENAI_MODEL_NAME'] = 'gpt-4o-mini'

# %% [markdown]
# ## Loading Tasks and Agents YAML files

# %%
# Define file paths for YAML configurations
files = {
    'agents': 'instructions/agents.yaml',
    'tasks': 'instructions/tasks.yaml'
}

# Load configurations from YAML files
configs = {}
for config_type, file_path in files.items():
    with open(file_path, 'r') as file:
        configs[config_type] = yaml.safe_load(file)

# Assign loaded configurations to specific variables
agents_config = configs['agents']
tasks_config = configs['tasks']

# %% [markdown]
# ## Create Pydantic Models for Structured Output

# %%
from typing import List
from pydantic import BaseModel, Field

class TaskEstimate(BaseModel):
    task_name: str = Field(..., description="Name of the task")
    estimated_time_hours: float = Field(..., description="Estimated time to complete the task in hours")
    required_resources: List[str] = Field(..., description="List of resources required to complete the task")

class Milestone(BaseModel):
    milestone_name: str = Field(..., description="Name of the milestone")
    tasks: List[str] = Field(..., description="List of task IDs associated with this milestone")

class ProjectPlan(BaseModel):
    tasks: List[TaskEstimate] = Field(..., description="List of tasks with their estimates")
    milestones: List[Milestone] = Field(..., description="List of project milestones")

# %% [markdown]
# ## Create Crew, Agents and Tasks

# %%
# Creating Agents
project_planning_agent = Agent(
  config=agents_config['project_planning_agent']
)

estimation_agent = Agent(
  config=agents_config['estimation_agent']
)

resource_allocation_agent = Agent(
  config=agents_config['resource_allocation_agent']
)

# Creating Tasks
task_breakdown = Task(
  config=tasks_config['task_breakdown'],
  agent=project_planning_agent
)

time_resource_estimation = Task(
  config=tasks_config['time_resource_estimation'],
  agent=estimation_agent
)

resource_allocation = Task(
  config=tasks_config['resource_allocation'],
  agent=resource_allocation_agent,
  output_pydantic=ProjectPlan # This is the structured output we want
)

# Creating Crew
crew = Crew(
  agents=[
    project_planning_agent,
    estimation_agent,
    resource_allocation_agent
  ],
  tasks=[
    task_breakdown,
    time_resource_estimation,
    resource_allocation
  ],
  verbose=True
)

# %% [markdown]
# ## Crew's Inputs

# %%
from IPython.display import display, Markdown

project = 'Website'
industry = 'Technology'
project_objectives = 'Create a website for a small business'
team_members = """
- John Doe (Project Manager)
- Jane Doe (Software Engineer)
- Bob Smith (Designer)
- Alice Johnson (QA Engineer)
- Tom Brown (QA Engineer)
"""
project_requirements = """
- Create a responsive design that works well on desktop and mobile devices
- Implement a modern, visually appealing user interface with a clean look
- Develop a user-friendly navigation system with intuitive menu structure
- Include an "About Us" page highlighting the company's history and values
- Design a "Services" page showcasing the business's offerings with descriptions
- Create a "Contact Us" page with a form and integrated map for communication
- Implement a blog section for sharing industry news and company updates
- Ensure fast loading times and optimize for search engines (SEO)
- Integrate social media links and sharing capabilities
- Include a testimonials section to showcase customer feedback and build trust
"""

# Format the dictionary as Markdown for a better display in Jupyter Lab
formatted_output = f"""
**Project Type:** {project}

**Project Objectives:** {project_objectives}

**Industry:** {industry}

**Team Members:**
{team_members}
**Project Requirements:**
{project_requirements}
"""
# Display the formatted output as Markdown
display(Markdown(formatted_output))
# Out:
# **Project Type:** Website
#
# **Project Objectives:** Create a website for a small business
#
# **Industry:** Technology
#
# **Team Members:**
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
# **Project Requirements:**
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust

# %% [markdown]
# ## Kicking off the crew

# %%
# The given Python dictionary
inputs = {
  'project_type': project,
  'project_objectives': project_objectives,
  'industry': industry,
  'team_members': team_members,
  'project_requirements': project_requirements
}

# Run the crew
result = crew.kickoff(
  inputs=inputs
)
# Out:
# # Agent: The Ultimate Project Planner
# ## Task: Carefully analyze the project_requirements for the Website project and break them down into individual tasks. Define each task's scope in detail, set achievable timelines, and ensure that all dependencies are accounted for:
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust
#
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: The Ultimate Project Planner
# ## Final Answer:
# ### Website Project Plan
#
# #### Project Requirements Breakdown
#
# 1. **Create a Responsive Design**
#    - **Description:** Develop a design that adapts to both desktop and mobile devices.
#    - **Scope:** Wireframes for various screen sizes, CSS media queries, testing on different devices.
#    - **Timeline:** 2 weeks (Start: Week 1, End: Week 2)
#    - **Dependencies:** None
#    - **Deliverables:** Completed wireframes, responsive design mockups.
#
# 2. **Implement Modern User Interface**
#    - **Description:** Design a visually appealing interface with a clean aesthetic.
#    - **Scope:** Create UI components (buttons, forms), color schemes, typography.
#    - **Timeline:** 3 weeks (Start: Week 3, End: Week 5)
#    - **Dependencies:** Completion of responsive design.
#    - **Deliverables:** UI designs in Adobe XD/Figma format.
#
# 3. **Develop a User-Friendly Navigation System**
#    - **Description:** Craft an intuitive menu structure for easy accessibility.
#    - **Scope:** Main navigation menu, dropdowns for services, breadcrumb trails.
#    - **Timeline:** 2 weeks (Start: Week 3, End: Week 4)
#    - **Dependencies:** Completion of UI design.
#    - **Deliverables:** Prototype navigation menus for review.
#
# 4. **Create an "About Us" Page**
#    - **Description:** Highlight the company's history and values.
#    - **Scope:** Write content, select images, design layout.
#    - **Timeline:** 1 week (Start: Week 5, End: Week 5)
#    - **Dependencies:** None
#    - **Deliverables:** Drafted page and layout for the "About Us" section.
#
# 5. **Design a "Services" Page**
#    - **Description:** Showcase the business's offerings with detailed descriptions.
#    - **Scope:** Create content for each service, design visuals.
#    - **Timeline:** 2 weeks (Start: Week 6, End: Week 7)
#    - **Dependencies:** Completion of the "About Us" page.
#    - **Deliverables:** "Services" page mockup and written content.
#
# 6. **Create a "Contact Us" Page**
#    - **Description:** Develop a page for communication with a form and map integration.
#    - **Scope:** Design the layout, create contact form, integrate Google Maps.
#    - **Timeline:** 1 week (Start: Week 7, End: Week 7)
#    - **Dependencies:** Completion of design for other pages.
#    - **Deliverables:** Completed "Contact Us" page.
#
# 7. **Implement a Blog Section**
#    - **Description:** For sharing industry news and updates.
#    - **Scope:** Design layout, create a content management system.
#    - **Timeline:** 3 weeks (Start: Week 8, End: Week 10)
#    - **Dependencies:** Completion of the "Services" page.
#    - **Deliverables:** Blog section prototype and first draft of blog post.
#
# 8. **Ensure Fast Loading Times & SEO Optimization**
#    - **Description:** Optimize website for speed and search engine rankings.
#    - **Scope:** Image optimization, caching strategies, SEO keyword integration.
#    - **Timeline:** 2 weeks (Start: Week 10, End: Week 11)
#    - **Dependencies:** Completion of website design and content creation.
#    - **Deliverables:** Report with load times and SEO scores pre- and post-optimization.
#
# 9. **Integrate Social Media Links**
#    - **Description:** Add links and sharing options for social media platforms.
#    - **Scope:** Identify social media accounts, add icons/links to the website.
#    - **Timeline:** 1 week (Start: Week 11, End: Week 11)
#    - **Dependencies:** Completion of all pages.
#    - **Deliverables:** Social Media integration on the website.
#
# 10. **Include a Testimonials Section**
#     - **Description:** Showcase customer feedback to build trust.
#     - **Scope:** Collect testimonials, design layout for displaying them.
#     - **Timeline:** 1 week (Start: Week 11, End: Week 11)
#     - **Dependencies:** Completion of services and about pages.
#     - **Deliverables:** Finalized testimonials section on the website.
#
# ### Team Roles
#
# - **John Doe (Project Manager):** Oversee the entire project timeline, resource allocation, and manage communication.
# - **Jane Doe (Software Engineer):** Responsible for technical implementation including coding the site.
# - **Bob Smith (Designer):** Handle design elements including user interface and user experience.
# - **Alice Johnson (QA Engineer):** Testing and quality assurance for design and functionality.
# - **Tom Brown (QA Engineer):** Support testing and ensure SEO compliance.
#
# ### Gantt Chart Visualization
#
# ```plaintext
# | Week   | Task                                         | Responsible   |
# |--------|----------------------------------------------|---------------|
# | 1      | Create Responsive Design                     | Bob Smith     |
# | 2      | Create Responsive Design                     | Bob Smith     |
# | 3      | Implement Modern User Interface              | Bob Smith     |
# | 3      | Develop Navigation System                    | Jane Doe      |
# | 4      | Develop Navigation System                    | Jane Doe      |
# | 5      | Create "About Us" Page                      | Jane Doe      |
# | 5      | Create "About Us" Page                      | Jane Doe      |
# | 6      | Design a "Services" Page                    | Jane Doe      |
# | 7      | Design a "Services" Page                    | Jane Doe      |
# | 7      | Create a "Contact Us" Page                  | Jane Doe      |
# | 8      | Implement Blog Section                       | Jane Doe      |
# | 9      | Implement Blog Section                       | Jane Doe      |
# | 10     | Ensuring Fast Loading Times & SEO           | Jane Doe      |
# | 10     | Ensure Fast Loading Times & SEO              | Jane Doe      |
# | 11     | Integrate Social Media links                 | Jane Doe      |
# | 11     | Include Testimonials Section                  | Jane Doe      |
#
# ```
#
# ### Outcome Description
# The project will lead to the successful creation of a professional, user-friendly website for the small business, enhancing its digital presence and ability to engage with customers. Each task is carefully planned with specific deadlines, responsible team members, and a clear flow of dependencies, ensuring cohesive teamwork and timely delivery. If executed as outlined, the website will not only attract visitors but also provide an optimal user experience that supports business goals effectively.
#
# This comprehensive plan ensures that every aspect of the website development is accounted for, executed efficiently, and aligned with the expectations of the business's online representation.
#
#
# # Agent: Expert Estimation Analyst
# ## Task: Thoroughly evaluate each task in the Website project to estimate the time, resources, and effort required. Use historical data, task complexity, and available resources to provide a realistic estimation for each task.
#
#
#
# # Agent: Expert Estimation Analyst
# ## Final Answer:
# ### Website Project Estimation Report
#
# #### Task 1: Create a Responsive Design
# - **Time Required:** 2 weeks
# - **Resources Needed:** 1 Designer (Bob Smith)
# - **Effort Estimation:** 80 hours in total (40 hours per week)
# - **Risks/Uncertainties:** Minor issues may arise during testing on various devices. Ensuring compatibility with all screen sizes can sometimes lead to unexpected adjustments.
#
# #### Task 2: Implement Modern User Interface
# - **Time Required:** 3 weeks
# - **Resources Needed:** 1 Designer (Bob Smith)
# - **Effort Estimation:** 120 hours in total (40 hours per week)
# - **Risks/Uncertainties:** Designing UI components can be subjective, which may require multiple revisions before approval.
#
# #### Task 3: Develop a User-Friendly Navigation System
# - **Time Required:** 2 weeks
# - **Resources Needed:** 1 Software Engineer (Jane Doe)
# - **Effort Estimation:** 80 hours in total (40 hours per week)
# - **Risks/Uncertainties:** Misunderstandings about the structure could lead to rework.
#
# #### Task 4: Create an "About Us" Page
# - **Time Required:** 1 week
# - **Resources Needed:** 1 Software Engineer (Jane Doe)
# - **Effort Estimation:** 40 hours
# - **Risks/Uncertainties:** Time may be required to gather images and authoritative content, which can delay finalization.
#
# #### Task 5: Design a "Services" Page
# - **Time Required:** 2 weeks
# - **Resources Needed:** 1 Software Engineer (Jane Doe)
# - **Effort Estimation:** 80 hours in total (40 hours per week)
# - **Risks/Uncertainties:** The detailed descriptions may require time for drafts and reviews with stakeholders.
#
# #### Task 6: Create a "Contact Us" Page
# - **Time Required:** 1 week
# - **Resources Needed:** 1 Software Engineer (Jane Doe)
# - **Effort Estimation:** 40 hours
# - **Risks/Uncertainties:** Integration with Google Maps may present API-related issues that will need resolution.
#
# #### Task 7: Implement a Blog Section
# - **Time Required:** 3 weeks
# - **Resources Needed:** 1 Software Engineer (Jane Doe)
# - **Effort Estimation:** 120 hours in total (40 hours per week)
# - **Risks/Uncertainties:** Content management system may require custom solutions depending on functionality needed.
#
# #### Task 8: Ensure Fast Loading Times & SEO Optimization
# - **Time Required:** 2 weeks
# - **Resources Needed:** 1 Software Engineer (Jane Doe), 1 QA Engineer (Tom Brown)
# - **Effort Estimation:** 80 hours in total (40 hours each for 2 weeks)
# - **Risks/Uncertainties:** SEO results can be unpredictable, and certain optimizations may not yield immediate results.
#
# #### Task 9: Integrate Social Media Links
# - **Time Required:** 1 week
# - **Resources Needed:** 1 Software Engineer (Jane Doe)
# - **Effort Estimation:** 40 hours
# - **Risks/Uncertainties:** Potential delays in getting necessary permissions or account information from stakeholders.
#
# #### Task 10: Include a Testimonials Section
# - **Time Required:** 1 week
# - **Resources Needed:** 1 Software Engineer (Jane Doe)
# - **Effort Estimation:** 40 hours
# - **Risks/Uncertainties:** Gathering testimonials requires time and effort from customers, which may affect scheduling.
#
# ### Summary of Overall Resource Requirements:
# - Total Duration: 16 weeks (4 months)
# - Total Resources: 1 Project Manager, 1 Software Engineer, 1 Designer, and 2 QA Engineers
# - Total Effort Across All Tasks: 680 hours
#
# ### Summary of Risks:
# - Potential delays due to dependencies, especially with design approvals.
# - Subjective feedback affecting design components leading to iterations.
# - External factors like customer feedback for testimonials could impact timelines.
#
# ### Conclusion
# The estimates provided allow for a well-structured approach to executing the website project efficiently and within budget. With careful consideration of risks and uncertainties, this thorough estimation report aims to provide a realistic guide while ensuring the website will successfully enhance the digital presence of the business. By preemptively identifying risks, the project team can formulate strategies to mitigate these challenges effectively.
#
#
# # Agent: Resource Allocation Strategist
# ## Task: Strategically allocate tasks for the Website project to team members based on their skills, availability, and current workload. Ensure that each task is assigned to the most suitable team member and that the workload is evenly distributed.
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
# # Agent: Resource Allocation Strategist
# ## Final Answer:
# ### Resource Allocation Chart for Website Project
#
# | Task                                      | Team Member(s)        | Start Date  | End Date    | Effort (hours) |
# |-------------------------------------------|-----------------------|-------------|-------------|----------------|
# | Create a Responsive Design                | Bob Smith (Designer)  | Week 1     | Week 2     | 80             |
# | Implement Modern User Interface           | Bob Smith (Designer)  | Week 3     | Week 5     | 120            |
# | Develop a User-Friendly Navigation System  | Jane Doe (Software Engineer) | Week 1     | Week 2     | 80             |
# | Create an "About Us" Page                | Jane Doe (Software Engineer) | Week 3     | Week 3     | 40             |
# | Design a "Services" Page                 | Jane Doe (Software Engineer) | Week 4     | Week 5     | 80             |
# | Create a "Contact Us" Page               | Jane Doe (Software Engineer) | Week 6     | Week 6     | 40             |
# | Implement a Blog Section                  | Jane Doe (Software Engineer) | Week 7     | Week 9     | 120            |
# | Ensure Fast Loading Times & SEO Optimization | Jane Doe (Software Engineer), Tom Brown (QA Engineer) | Week 10   | Week 11   | 80             |
# | Integrate Social Media Links              | Jane Doe (Software Engineer) | Week 12   | Week 12   | 40             |
# | Include a Testimonials Section            | Jane Doe (Software Engineer) | Week 13   | Week 13   | 40             |
#
# ### Summary of Rationale Behind Each Allocation Decision
#
# 1. **Task 1: Create a Responsive Design** - Assigned to Bob Smith (Designer) as this task directly aligns with his design expertise and is critical for the project to move forward to implementation phases.
#
# 2. **Task 2: Implement Modern User Interface** - Bob Smith is again assigned due to his skills as a designer, and since this UI task also requires a designer's touch, his continuous involvement ensures design consistency.
#
# 3. **Task 3: Develop a User-Friendly Navigation System** - Jane Doe is assigned because implementing navigation requires programming knowledge, and she has the capacity to handle this task (40 hours/week).
#
# 4. **Task 4: Create an "About Us" Page** - A short-term task fitting Jane Doe's skill set as it is a straightforward programming task designed to complement her larger assignments.
#
# 5. **Task 5: Design a "Services" Page** - This task follows the "About Us" Page and is meant to further develop Jane Doe’s consistent work stream, allowing her to maintain focus on user-centered page development.
#
# 6. **Task 6: Create a "Contact Us" Page** - Another task for Jane Doe, this one is brief and allows for completion following the previous services task, while also keeping her in line with implementing forms and layouts.
#
# 7. **Task 7: Implement a Blog Section** - Given the complexity and effort required, Jane Doe will work on this next following the brief tasks ensuring she has completed the foundational elements first.
#
# 8. **Task 8: Ensure Fast Loading Times & SEO Optimization** - Collaboratively assigned to Jane Doe (Software Engineer) and Tom Brown (QA Engineer) to cover both development and testing aspects, as optimizing SEO inherently requires functional review post-implementation.
#
# 9. **Task 9: Integrate Social Media Links** - Assigned solely to Jane Doe due to her expertise in back-end programming, which this task requires.
#
# 10. **Task 10: Include a Testimonials Section** - Tasked again to Jane Doe to allow her to finish this assembling of various testimonials—capping her role after substantial development work.
#
# Overall, the allocation plan ensures balance in workload and skill utilization while maintaining a steady schedule for task completion. Each team member is engaged appropriately based on their defined roles, balancing the overall project efforts and mitigating risks through clear responsibility allocation. This strategic approach should maximize efficiency leading to successful project execution.

# %% [markdown]
# ## Usage Metrics and Costs

# %%
import pandas as pd

costs = 0.150 * (crew.usage_metrics.prompt_tokens + crew.usage_metrics.completion_tokens) / 1_000_000
print(f"Total costs: ${costs:.4f}")

# Convert UsageMetrics instance to a DataFrame
df_usage_metrics = pd.DataFrame([crew.usage_metrics.dict()])
df_usage_metrics
# Out:
# Total costs: $0.0027
#    total_tokens  prompt_tokens  completion_tokens  successful_requests
# 0         17980          10966               7014                    9

# %% [markdown]
# ## Result

# %%
result.pydantic.dict()
# Out:
# {'tasks': [{'task_name': 'Create a Responsive Design',
#    'estimated_time_hours': 80.0,
#    'required_resources': ['Bob Smith (Designer)']},
#   {'task_name': 'Implement Modern User Interface',
#    'estimated_time_hours': 120.0,
#    'required_resources': ['Bob Smith (Designer)']},
#   {'task_name': 'Develop a User-Friendly Navigation System',
#    'estimated_time_hours': 80.0,
#    'required_resources': ['Jane Doe (Software Engineer)']},
#   {'task_name': "Create an 'About Us' Page",
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe (Software Engineer)']},
#   {'task_name': "Design a 'Services' Page",
#    'estimated_time_hours': 80.0,
#    'required_resources': ['Jane Doe (Software Engineer)']},
#   {'task_name': "Create a 'Contact Us' Page",
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe (Software Engineer)']},
#   {'task_name': 'Implement a Blog Section',
#    'estimated_time_hours': 120.0,
#    'required_resources': ['Jane Doe (Software Engineer)']},
#   {'task_name': 'Ensure Fast Loading Times & SEO Optimization',
#    'estimated_time_hours': 80.0,
#    'required_resources': ['Jane Doe (Software Engineer)',
#     'Tom Brown (QA Engineer)']},
#   {'task_name': 'Integrate Social Media Links',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe (Software Engineer)']},
#   {'task_name': 'Include a Testimonials Section',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe (Software Engineer)']}],
#  'milestones': [{'milestone_name': 'Website Design Complete',
#    'tasks': ['Create a Responsive Design', 'Implement Modern User Interface']},
#   {'milestone_name': 'Basic Pages Developed',
#    'tasks': ['Develop a User-Friendly Navigation System',
#     "Create an 'About Us' Page",
#     "Design a 'Services' Page",
#     "Create a 'Contact Us' Page"]},
#   {'milestone_name': 'Blog Section Live',
#    'tasks': ['Implement a Blog Section']},
#   {'milestone_name': 'SEO Optimization',
#    'tasks': ['Ensure Fast Loading Times & SEO Optimization']},
#   {'milestone_name': 'Social Media Integration',
#    'tasks': ['Integrate Social Media Links']},
#   {'milestone_name': 'Testimonials Section Complete',
#    'tasks': ['Include a Testimonials Section']}]}

# %% [markdown]
# ## Inspect further

# %%
tasks = result.pydantic.dict()['tasks']
df_tasks = pd.DataFrame(tasks)

# Display the DataFrame as an HTML table
df_tasks.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_229e2 th {
#   font-size: 120%;
# }
# #T_229e2  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_229e2" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_229e2_level0_col0" class="col_heading level0 col0" >task_name</th>
#       <th id="T_229e2_level0_col1" class="col_heading level0 col1" >estimated_time_hours</th>
#       <th id="T_229e2_level0_col2" class="col_heading level0 col2" >required_resources</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_229e2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_229e2_row0_col0" class="data row0 col0" >Create a Responsive Design</td>
#       <td id="T_229e2_row0_col1" class="data row0 col1" >80.000000</td>
#       <td id="T_229e2_row0_col2" class="data row0 col2" >['Bob Smith (Designer)']</td>
#     </tr>
#     <tr>
#       <th id="T_229e2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_229e2_row1_col0" class="data row1 col0" >Implement Modern User Interface</td>
#       <td id="T_229e2_row1_col1" class="data row1 col1" >120.000000</td>
#       <td id="T_229e2_row1_col2" class="data row1 col2" >['Bob Smith (Designer)']</td>
#     </tr>
#     <tr>
#       <th id="T_229e2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_229e2_row2_col0" class="data row2 col0" >Develop a User-Friendly Navigation System</td>
#       <td id="T_229e2_row2_col1" class="data row2 col1" >80.000000</td>
#       <td id="T_229e2_row2_col2" class="data row2 col2" >['Jane Doe (Software Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_229e2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_229e2_row3_col0" class="data row3 col0" >Create an 'About Us' Page</td>
#       <td id="T_229e2_row3_col1" class="data row3 col1" >40.000000</td>
#       <td id="T_229e2_row3_col2" class="data row3 col2" >['Jane Doe (Software Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_229e2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_229e2_row4_col0" class="data row4 col0" >Design a 'Services' Page</td>
#       <td id="T_229e2_row4_col1" class="data row4 col1" >80.000000</td>
#       <td id="T_229e2_row4_col2" class="data row4 col2" >['Jane Doe (Software Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_229e2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_229e2_row5_col0" class="data row5 col0" >Create a 'Contact Us' Page</td>
#       <td id="T_229e2_row5_col1" class="data row5 col1" >40.000000</td>
#       <td id="T_229e2_row5_col2" class="data row5 col2" >['Jane Doe (Software Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_229e2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_229e2_row6_col0" class="data row6 col0" >Implement a Blog Section</td>
#       <td id="T_229e2_row6_col1" class="data row6 col1" >120.000000</td>
#       <td id="T_229e2_row6_col2" class="data row6 col2" >['Jane Doe (Software Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_229e2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_229e2_row7_col0" class="data row7 col0" >Ensure Fast Loading Times & SEO Optimization</td>
#       <td id="T_229e2_row7_col1" class="data row7 col1" >80.000000</td>
#       <td id="T_229e2_row7_col2" class="data row7 col2" >['Jane Doe (Software Engineer)', 'Tom Brown (QA Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_229e2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_229e2_row8_col0" class="data row8 col0" >Integrate Social Media Links</td>
#       <td id="T_229e2_row8_col1" class="data row8 col1" >40.000000</td>
#       <td id="T_229e2_row8_col2" class="data row8 col2" >['Jane Doe (Software Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_229e2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_229e2_row9_col0" class="data row9 col0" >Include a Testimonials Section</td>
#       <td id="T_229e2_row9_col1" class="data row9 col1" >40.000000</td>
#       <td id="T_229e2_row9_col2" class="data row9 col2" >['Jane Doe (Software Engineer)']</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Inspecting Milestones

# %%
milestones = result.pydantic.dict()['milestones']
df_milestones = pd.DataFrame(milestones)

# Display the DataFrame as an HTML table
df_milestones.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_01fb7 th {
#   font-size: 120%;
# }
# #T_01fb7  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_01fb7" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_01fb7_level0_col0" class="col_heading level0 col0" >milestone_name</th>
#       <th id="T_01fb7_level0_col1" class="col_heading level0 col1" >tasks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_01fb7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_01fb7_row0_col0" class="data row0 col0" >Website Design Complete</td>
#       <td id="T_01fb7_row0_col1" class="data row0 col1" >['Create a Responsive Design', 'Implement Modern User Interface']</td>
#     </tr>
#     <tr>
#       <th id="T_01fb7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_01fb7_row1_col0" class="data row1 col0" >Basic Pages Developed</td>
#       <td id="T_01fb7_row1_col1" class="data row1 col1" >['Develop a User-Friendly Navigation System', "Create an 'About Us' Page", "Design a 'Services' Page", "Create a 'Contact Us' Page"]</td>
#     </tr>
#     <tr>
#       <th id="T_01fb7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_01fb7_row2_col0" class="data row2 col0" >Blog Section Live</td>
#       <td id="T_01fb7_row2_col1" class="data row2 col1" >['Implement a Blog Section']</td>
#     </tr>
#     <tr>
#       <th id="T_01fb7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_01fb7_row3_col0" class="data row3 col0" >SEO Optimization</td>
#       <td id="T_01fb7_row3_col1" class="data row3 col1" >['Ensure Fast Loading Times & SEO Optimization']</td>
#     </tr>
#     <tr>
#       <th id="T_01fb7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_01fb7_row4_col0" class="data row4 col0" >Social Media Integration</td>
#       <td id="T_01fb7_row4_col1" class="data row4 col1" >['Integrate Social Media Links']</td>
#     </tr>
#     <tr>
#       <th id="T_01fb7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_01fb7_row5_col0" class="data row5 col0" >Testimonials Section Complete</td>
#       <td id="T_01fb7_row5_col1" class="data row5 col1" >['Include a Testimonials Section']</td>
#     </tr>
#   </tbody>
# </table>
