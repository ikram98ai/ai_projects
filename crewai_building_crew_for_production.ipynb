# %% [markdown]
# # Building Your Crew for Production

# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from helper import load_env
load_env()

# %% [markdown]
# ## Creating a new project

# %%
! crewai create crew content_creation --provider openai
# Out:
# Creating folder content_creation...
#   - Created content_creation/.gitignore
#   - Created content_creation/pyproject.toml
#   - Created content_creation/README.md
#   - Created content_creation/src/content_creation/__init__.py
#   - Created content_creation/src/content_creation/main.py
#   - Created content_creation/src/content_creation/crew.py
#   - Created content_creation/src/content_creation/tools/custom_tool.py
#   - Created content_creation/src/content_creation/tools/__init__.py
#   - Created content_creation/src/content_creation/config/agents.yaml
#   - Created content_creation/src/content_creation/config/tasks.yaml
# Crew content_creation created successfully!

# %% [markdown]
# ## Setting up the Environment

# %%
! cd content_creation && crewai install
# Out:
# Using CPython 3.11.9 interpreter at: /usr/local/bin/python
# Creating virtual environment at: .venv
# Resolved 222 packages in 2.23s
# Building content-creation @ file:///home/jovyan/work/L13/content_creation
# Building content-creation @ file:///home/jovyan/work/L13/content_creation
# ⠙ Preparing packages... (0/217)
# Building content-creation @ file:///home/jovyan/work/L13/content_creation2A
# ⠙ Preparing packages... (0/217)
# Building content-creation @ file:///home/jovyan/work/L13/content_creation2A
# ⠙ Preparing packages... (0/217)
# sympy      ------------------------------     0 B/5.90 MiB
# Building content-creation @ file:///home/jovyan/work/L13/content_creation3A
# ⠙ Preparing packages... (0/217)
# cryptography ------------------------------     0 B/3.80 MiB
# sympy      ------------------------------     0 B/5.90 MiB
# Building content-creation @ file:///home/jovyan/work/L13/content_creation4A
# ⠙ Preparing packages... (0/217)
# ...

# %% [markdown]
# ## Setting Environment Variables

# %%
! cat content_creation/.env
# Out:
# OPENAI_API_KEY=YOUR_API_KEY_HERE

# %% [markdown]
# ## Running the Crew

# %%
! cd content_creation && crewai run
# Out:
# Running the Crew
# # Agent: AI LLMs Senior Data Researcher
# ## Task: Conduct a thorough research about AI LLMs Make sure you find any interesting and relevant information given the current year is 2024.
#
#
#
# # Agent: AI LLMs Senior Data Researcher
# ## Final Answer:
# Here are ten bullet points outlining the most relevant information about AI Large Language Models (LLMs) as of 2024:
#
# 1. **Continued Advancements in Scaling**: AI researchers are focusing on scaling LLMs beyond trillions of parameters, with some models approaching quintillions of parameters to enhance their contextual understanding and generation capabilities.
#
# 2. **Multimodal Capabilities**: There is a significant push towards developing multimodal LLMs that integrate text, image, and audio processing. This allows models to generate content that is more contextually aware across different media types, improving applications in fields like education and marketing.
#
# ...

# %% [markdown]
# ## Flows CLI - Command Line Interface

# %%
! crewai create flow new_flow
# Out:
# Creating flow new_flow...
# Flow new_flow created successfully!

# %%
! ls -1 new_flow
# Out:
# README.md
# pyproject.toml
# src
# tests

# %%
! ls -1 new_flow/src/new_flow/
# Out:
# __init__.py
# crews
# main.py
# tools
